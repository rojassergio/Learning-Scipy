# %% [markdown]
# # <center><font color=red>     An&aacute;lisis Num&eacute;rico y C&oacute;mputo Cient&iacute;fico   v&iacute;a Python   usando la carpeta de notas IPython (IPython Notebook): un breve comentario sobre su utilidad en el sal&oacute;n de clases </font></center>

# %% [markdown]
# >### [Sergio Rojas](http://prof.usb.ve/srojas)<br>
# [Departamento de F&iacute;sica](http://www.fis.usb.ve/), [Universidad Sim&oacute;n Bol&iacute;var](http://www.usb.ve/), [Venezuela](http://es.wikipedia.org/wiki/Venezuela)

# %% [markdown]
# >###Content under [Creative Commons Attribution license CC-BY 4.0](http://creativecommons.org/licenses/by/4.0/), [code under MIT license (c)](http://en.wikipedia.org/wiki/MIT_License)2015 Sergio Rojas (srojas@usb.ve).###

# %% [markdown]
# ##Este Notebook se puede visualizar como un archivo HTML [siguiendo este enlace](http://nbviewer.ipython.org/github/rojassergio/Learning-Scipy/blob/master/Other_IPhythonNotes/Numerical_Computing_via_IPython.ipynb)##
#
# ##La fuente de este IPython Notebook se puede obtener [en este enlace](https://github.com/rojassergio/Learning-Scipy/Other_IPhythonNotes/Numerical_Computing_via_IPython.ipynb)##

# %% [markdown]
# #<font color=red>RESUMEN</font>#

# %% [markdown]
# [Python](https://www.python.org/) es un lenguaje
# de programaci&oacute;n
# [multi-paradigma](http://en.wikipedia.org/wiki/Programming_paradigm#Multi-paradigm) que por
#  satisfacer las exigencias de un lenguaje de programaci&oacute;n
# moderno (como programaci&oacute;n en funciones y orientada a objeto)
# <b>ha ganado mucha popularidad</b> en los &uacute;ltimos a&ntilde;os en el
# medio de la computaci&oacute;n cient&iacute;fica, gracias
# a que se han incorporado al mismo m&oacute;dulos que facilitan
# la tarea de c&oacute;mputo cient&iacute;fico tales como
# [NumPy](http://www.numpy.org/) y
# [SciPy](http://www.scipy.org/)
#  (que incorporan bibliotecas de c&aacute;lculo en
# pr&aacute;cticamente todas las &aacute;reas que abarca
#  el c&oacute;mputo num&eacute;rico), [Matplotlib](http://matplotlib.org/) (para
# satisfacer
# las necesidades de visualizaci&oacute;n), [SymPy](http://www.sympy.org/en/index.html) (para cubrir las necesidades de ejecutar c&oacute;mputo algebra&iacute;co o matem&aacute;tica simb&oacute;lica) y
# [mucho m&aacute;s](https://docs.python.org/3/py-modindex.html).
#
# En ese desarrollo, tambi&eacute;n se han incorporado a
# Python ambientes de programaci&oacute;n que hacen m&aacute;s
# amigable y eficiente la tarea de programar. Uno de tales ambientes
# es la [consola IPython](http://ipython.org/),
# que se ha extendido o ha evolucionado a la forma de una
# [libreta de notas (IPython Notebook)](http://ipython.org/notebook.html)
#  que favorece la integraci&oacute;n en un navegador de la Internet,
# no solo el ambiente de programaci&oacute;n Python, sino tambi&eacute;n
# texto o notas asociados a los c&oacute;mputos que se
# realizan. Cabe mencionar que
# esta presentaci&oacute;n es uno de los tantos [ejemplos](https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks) que se han escrito
# en el IPython Notebook.
#
# As&iacute;, en esta presentaci&oacute;n estaremos conversando sobre c&oacute;mo
# enriquecer
# las clases de c&oacute;mputo num&eacute;rico con el IPython Notebook,
# y como ejemplo ilustrativo estaremos abordando el tema
# de estudio obligatorio en cualquier curso introductorio
# del c&oacute;mputo cient&iacute;fico, como lo son el tema de la **soluci&oacute;n
# num&eacute;rica de ecuaciones diferenciales ordinarias** y el tema
# de **regresi&oacute;n** (**o ajuste de curvas**), pero trataremos este &uacute;ltimo desde el punto de
# vista del [aprendizaje de aut&oacute;matas o de m&aacute;quinas (Machine Learning)](http://en.wikipedia.org/wiki/Machine_learning).

# %% [markdown]
# #<font color=red>Sobre el IPython Notebook</font>#

# %% [markdown]
# [Aunque ideado sin ser ello su objetivo principal](http://blog.fperez.org/2012/01/ipython-notebook-historical.html),
# el IPython Notebook ha evolucionado como
# un espl&eacute;ndido y vers&aacute;til
# recurso computacional de
# [fuente abierta](http://es.wikipedia.org/wiki/C%C3%B3digo_abierto)
# que, por su naturaleza interactiva
# y funcionalidad para combinar texto, computaci&oacute;n num&eacute;rica &oacute; simb&oacute;lica,
# visualizaci&oacute;n y v&iacute;deos, de manera simple y sencilla en un mismo documento,
#  nos permite enriquecer el proceso
# ense&ntilde;anza-aprendizaje en pr&aacute;cticamente todas las asignaturas que
# se ofrecen o dictan en todos los niveles del sistema educativo.
# Para ello, el uso de &eacute;ste excelente recurso lo facilita el hecho de que
# existen distribuciones gratuitas de Python, f&aacute;ciles
# de instalar en cualquier sistema computacional con requerimientos m&iacute;nimos
# de hardware y
#   que
#  (como parte del proceso de instalaci&oacute;n) incluyen la instalaci&oacute;n
#  del IPython Notebook con funcionalidad completa.
# Dos de esas distribuciones son
# [Anaconda](http://continuum.io/downloads) y
# [Enthought Canopy](https://store.enthought.com/downloads/).
#
# Adicionalmente, no es obligatorio tener que instalar el
# IPython Notebook en nuestro ambiente computacional dado
# que tal herramienta se puede ejecutar (si contamos
# con buena conectividad a Internet) v&iacute;a la Web mediante servicios
# gratuitos como [SageMathCloud](https://cloud.sagemath.com/)
#  o con restricciones como [Wakari](https://wakari.io/).
# M&aacute;s a&uacute;n, igualmente podemos utilizar este recurso de manera pasiva
# una vez que encontramos alg&uacute;n material que deseamos utilizar en clase
# v&iacute;a el servicio gratuito [nbviewer](http://nbviewer.ipython.org/)
# que permite mostrar en nuestro navegador de la Web (Web browser)
# el contenido del IPython Notebook que encontremos.
#
# Por ejemplo, supongamos que deseamos mostrar el contenido de uno de los IPython Notebook
# que est&aacute;n disponible en el conjunto de
# notas [Lectures on scientific computing with python, as IPython notebooks](https://github.com/jrjohansson/scientific-python-lectures).
# Ello requiere que identifiquemos la direcci&oacute;n completa del enlace en Internet que conduce al
# IPython Notebook que deseamos mostrar. Para los efectos del presente ejemplo, hemos seleccionado que las notas a mostrar sean las que corresponden al enlace que se especifica como [https://github.com/jrjohansson/scientific-python-lectures/blob/master/Lecture-0-Scientific-Computing-with-Python.ipynb]. Una vez seleccionado, el enlace
#  lo copiamos en el espacio que provee [nbviewer](http://nbviewer.ipython.org/)
#  para tal fin (justo debajo de "<em>A simple way to share Jupyter Notebooks</em>")
# y precionamos (hacemos click) con el bot&oacute;n derecho del rat&oacute;n en el <b><em>Go!</em></b> que aparece al final del espacio
# donde copiamos la direcci&oacute;n web del IPython Notebook. Con este simple procedimiento
# podemos visualizar en nuestro navegador de Internet el contenido del
#  IPython Notebook [http://nbviewer.ipython.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-0-Scientific-Computing-with-Python.ipynb](http://nbviewer.ipython.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-0-Scientific-Computing-with-Python.ipynb).
#
# En este respecto, para formarnos una mejor
# impresi&oacute;n de lo que podemos obtener o hacer con el IPython Notebook antes de decidir instalarlo en nuestro computador,
# nos podemos entretener un poco explorando
# esta [galer&iacute;a de (interesantes) IPython Notebooks](https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks) o la colecci&oacute;n
# de ejemplos encontrados en
# [http://nbipython.blogspot.com/](http://nbipython.blogspot.com/).

# %% [markdown]
# #<font color=red>Ejecutando el IPython Notebook</font>#

# %% [markdown]
# Una vez instalado, el IPython Notebook se activa desde un terminal (linux)
# [ejecutando el comando](http://ipython.org/ipython-doc/3/notebook/notebook.html#starting-the-notebook-server):
# <pre><code>
# ipython notebook
# </code></pre>

# %% [markdown]
# <font color=red><h1>Recursos para incluir Texto, Im&aacute;genes y Videos en un IPython Notebook </h1></font>

# %% [markdown]
# ##TEXTO##

# %% [markdown]
#    El IPython notebook se ha enriquecido de manera tal que permite combinar la escritura de texto y expresiones matem&aacute;ticas en [*HTML*](http://en.wikipedia.org/wiki/HTML) y [$\LaTeX$](http://www.latex-project.org/) mediante el uso
#    [Markdown](http://daringfireball.net/projects/markdown/) y
#    [MathJax](http://www.mathjax.org/index.html).
#
#    Informaci&oacute;n adicional sobre este particular se encuentra en
#    [Typesetting Math Using MathJax](http://nbviewer.ipython.org/github/odewahn/ipynb-examples/blob/master/Typesetting%20Math%20Using%20MathJax.ipynb) y [IPython's Rich Display System](http://nbviewer.ipython.org/github/adrn/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb)
#
#    \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\   \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\ \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\ \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# ##IM&Aacute;GENES##
# Para informaci&oacute;n adicional consultar el enlace [Incluir im&aacute;genes en el IPython Notebook](http://nbviewer.ipython.org/github/adrn/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb).

# %%
from IPython.display import Image
Image(url='http://ipython.org/_static/IPy_header.png')
# Out:
# <img src="http://ipython.org/_static/IPy_header.png"/>

# %%
Image(filename='../img/IPy_header.png')

# %% [markdown]
# ##VIDEOS##
# Para informaci&oacute;n adicional consultar en los enlaces
# [Videos en el IPython Notebook](http://nbviewer.ipython.org/github/adrn/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb)
# e
# [Incluir videos en el IPython Notebook](http://nbviewer.ipython.org/github/fperez/ipynb-embed-video/blob/master/EmbeddedVideo.ipynb).

# %%
from IPython.display import YouTubeVideo
#----
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
#-----
YouTubeVideo('F4rFuIb1Ie4')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/F4rFuIb1Ie4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # <center> <font color=red>Algunos comandos para operar en el IPython Notebook v&iacute;a el teclado</font> </center>

# %% [markdown]
# **Comando** | **Lo que hace**
# --- | ---
# Presionar **Enter/Return** | Activa el modo de Edici&oacute;n
# Presionar **ESC** | Activa el modo de comando
# **ESC** seguido de **h** | Muestra la lista de comandos
# **ESC** seguido de **a** | Inserta una celda de comando sobre (arriba de) la actual
# **ESC** seguido de **b** | Inserta una celda de comando debajo de la actual
# **ESC** seguido de **CTRL-k** | Mueve la celda actual hacia arriba
# **ESC** seguido de **CTRL-j** | Mueve la celda actual hacia abajo
# **ESC** seguido de **c** y luego **v** | Copia el contenido de la celda actual debajo de &eacute;sta
# **ESC** seguido de **c** y luego **SHIFT-v** | Copia el contenido de la celda actual arriba de &eacute;sta
# **ESC** seguido de **s** | Guarda en disco el Notebook

# %% [markdown]
# ###**Para m&aacute;s detalles consultar los enlaces previamente mencionados o alg&uacute;n texto sobre  IPython Notebook, tal como** [**L. Felipe Martins**](https://www.packtpub.com/big-data-and-business-intelligence/ipython-notebook-essentials) (2014) IPython Notebook Essentials, Packt Publishing.###

# %% [markdown]
# # <center> EJEMPLO COMPUTACIONAL I: <font color=red>SOLUCI&Oacute;N NUM&Eacute;RICA DE ECUACIONES DIFERENCIALES ORDINARIAS</font> </center>

# %% [markdown]
# ##  $$ \boxed{ \begin{equation} \frac{d\mathbf{y}}{dt} = f(t,\mathbf{y}), \,\,\, \mathbf{y}(t)=(y_1(t),\dots,y_n(t)), \,\,\,t \in \mathbb{R} \end{equation} }$$

# %% [markdown]
# <font color=red><b>Click the left mouse button on the left of the output
# of the following command to shorten the displayed output in a elevator
# type window</b></font>

# %%
import scipy.integrate
help(scipy.integrate.ode)
# Out:
# Help on class ode in module scipy.integrate._ode:
#
# class ode(__builtin__.object)
#  |  A generic interface class to numeric integrators.
#  |
#  |  Solve an equation system :math:`y'(t) = f(t,y)` with (optional) ``jac = df/dy``.
#  |
#  |  Parameters
#  |  ----------
#  |  f : callable ``f(t, y, *f_args)``
#  |      Rhs of the equation. t is a scalar, ``y.shape == (n,)``.
#  |      ``f_args`` is set by calling ``set_f_params(*args)``.
#  |      `f` should return a scalar, array or list (not a tuple).
#  |  jac : callable ``jac(t, y, *jac_args)``
#  |      Jacobian of the rhs, ``jac[i,j] = d f[i] / d y[j]``.
#  |      ``jac_args`` is set by calling ``set_f_params(*args)``.
#  |
#  |  Attributes
#  |  ----------
#  |  t : float
#  |      Current time.
#  |  y : ndarray
#  |      Current variable values.
#  |
#  |  See also
#  |  --------
#  |  odeint : an integrator with a simpler interface based on lsoda from ODEPACK
#  |  quad : for finding the area under a curve
#  |
#  |  Notes
# ...

# %% [markdown]
# <b>Let's solve via <em>ode</em> the following initial value problem (<font color=red>for additional details, pleae see the corresponding section for this chapter in the book</font></b>)

# %% [markdown]
# ##  $$ \boxed{ \begin{equation} y' = - 20 y, \,\,\, y(0)=1 \end{equation} }$$

# %%
import numpy
from scipy.integrate import ode
f=lambda t,y: -20*y        # The ODE
actual_solution=lambda t:numpy.exp(-20*t)  # actual solution
dt=0.01            # time step
solver=ode(f).set_integrator('dop853')  # solver
solver.set_initial_value(1,0)      # initial value
print("\t t \t    (Nunm Sol) \t \t (Exact Sol) \t \t Rel Error (%)")
while solver.successful() and solver.t<=1+dt:
   # solve the equation at succesive time steps,
   # until the time is greater than 1
   # but make sure that the solution is successful
   relerror = ((actual_solution(solver.t) - solver.y[0])/actual_solution(solver.t))*100
   print("\t{0:4.3f} {1:20.16f}  {2:20.16f} {3:20.16f}".format(solver.t, solver.y[0], 
                                                actual_solution(solver.t), relerror))
   # We compare each numerical solution with the actual
   # solution of the ODE
   solver.integrate(solver.t + dt)    # solve next step
# Out:
# 	 t 	    (Nunm Sol) 	 	 (Exact Sol) 	 	 Rel Error (%)
# 	0.000   1.0000000000000000    1.0000000000000000   0.0000000000000000
# 	0.010   0.8187307530780106    0.8187307530779818  -0.0000000000035121
# 	0.020   0.6703200460356864    0.6703200460356393  -0.0000000000070225
# 	0.030   0.5488116360940843    0.5488116360940264  -0.0000000000105598
# 	0.040   0.4493289641172848    0.4493289641172216  -0.0000000000140838
# 	0.050   0.3678794411715071    0.3678794411714423  -0.0000000000175944
# 	0.060   0.3011942119122656    0.3011942119122020  -0.0000000000211212
# 	0.070   0.2465969639416671    0.2465969639416064  -0.0000000000246156
# 	0.080   0.2018965179947122    0.2018965179946554  -0.0000000000281547
# 	0.090   0.1652988882216389    0.1652988882215866  -0.0000000000316681
# 	0.100   0.1353352832366604    0.1353352832366127  -0.0000000000351930
# 	0.110   0.1108031583623768    0.1108031583623339  -0.0000000000387264
# ...

# %%
help(scipy.integrate.odeint)
# Out:
# Help on function odeint in module scipy.integrate.odepack:
#
# odeint(func, y0, t, args=(), Dfun=None, col_deriv=0, full_output=0, ml=None, mu=None, rtol=None, atol=None, tcrit=None, h0=0.0, hmax=0.0, hmin=0.0, ixpr=0, mxstep=0, mxhnil=0, mxordn=12, mxords=5, printmessg=0)
#     Integrate a system of ordinary differential equations.
#
#     Solve a system of ordinary differential equations using lsoda from the
#     FORTRAN library odepack.
#
#     Solves the initial value problem for stiff or non-stiff systems
#     of first order ode-s::
#
#         dy/dt = func(y,t0,...)
#
#     where y can be a vector.
#
#     Parameters
#     ----------
#     func : callable(y, t0, ...)
#         Computes the derivative of y at t0.
#     y0 : array
#         Initial condition on y (can be a vector).
#     t : array
#         A sequence of time points for which to solve for y.  The initial
#         value point should be the first element of this sequence.
#     args : tuple, optional
# ...

# %% [markdown]
# ## Atractor de Lorenz

# %% [markdown]
# ##  $$ \boxed{ \left\{   \begin{align} \frac{dx}{dt} & = \sigma(y-x) \\ \frac{dy}{dt} & = r x - y - x z \\ \frac{dz}{dt} & = x y - b z   \end{align}  \right. }$$

# %%
import numpy
from numpy import linspace
import scipy
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
sigma=10.0
b=8.0/3.0
r=28.0
f = lambda x,t: [sigma*(x[1]-x[0]),
                 r*x[0]-x[1]-x[0]*x[2],
                 x[0]*x[1]-b*x[2]]

t=linspace(0,20,2000); y0=[5.0,5.0,5.0]
solution=odeint(f,y0,t)
X=solution[:,0]; Y=solution[:,1]; Z=solution[:,2]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
theplot = plt.figure().gca(projection='3d')
theplot.plot(X, Y, Z)
theplot.set_xlabel('X')
theplot.set_ylabel('Y')
theplot.set_zlabel('Z')

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

theplot.set_title(r'Soluci\'on del sistema de Lorenz', fontsize=16, color='gray')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15.0, 5.0)
plt.subplot(121) 
plt.plot(t,Z)
plt.xlabel('t', fontsize=16)
plt.ylabel('Z', fontsize=16)
#
plt.subplot(122)
plt.plot(Y,Z)
plt.xlabel('Y', fontsize=16)
plt.ylabel('Z', fontsize=16)
plt.show()

# %% [markdown]
# ###**Para m&aacute;s detalles sobre SciPy consultar los enlaces previamente mencionados o alg&uacute;n texto sobre el tema, como:**###

# %%
Image(url='https://dz13w8afd47il.cloudfront.net/sites/default/files/imagecache/ppv4_main_book_cover/1803_Learning%20SciPy%20for%20Numerical%20and%20Scientific%20Computing.jpg')
# Out:
# <img src="https://dz13w8afd47il.cloudfront.net/sites/default/files/imagecache/ppv4_main_book_cover/1803_Learning%20SciPy%20for%20Numerical%20and%20Scientific%20Computing.jpg"/>

# %% [markdown]
# ##[**Sergio J. Rojas G., Erik A Christensen y Francisco J. Blanco-Silva**](https://www.packtpub.com/big-data-and-business-intelligence/learning-scipy-numerical-and-scientific-computing-second-edition) (2015) Learning SciPy for Numerical and Scientific Computing, Second Edition, Packt Publishing.##

# %% [markdown]
# # <center> EJEMPLO COMPUTACIONAL II: <font color=red>AJUSTE DE CURVAS</font> </center>

# %% [markdown]
# ##  <center>     <font color=red> TO BE CONTINUED </font> </center>

# %% [markdown]
# >###Content under [Creative Commons Attribution license CC-BY 4.0](http://creativecommons.org/licenses/by/4.0/), [code under MIT license (c)](http://en.wikipedia.org/wiki/MIT_License)2015 Sergio Rojas (srojas@usb.ve).###
